# %% [markdown]
# %matplotlib notebook
# import numpy as np
# import matplotlib.pyplot as plt
# import time
#
# m = 100
# n = 100
# matrix = np.random.normal(0,1,m*n).reshape(m,n)
#
# fig = plt.figure()
# ax = fig.add_subplot(111)
# plt.ion()
#
# fig.show()
# fig.canvas.draw()
#
# for i in range(0,100):
#     ax.clear()
#     ax.plot(matrix[i,:])
#     fig.canvas.draw()
#     time.sleep(0.1)

# %%
m = 100
n = 100
matrix = np.random.normal(0,1,m*n).reshape(m,n)

timepoints = [] # [0.0]
ydata =   [] # [0.0, 0.0] 
#[] 
yrange = [-0.1,20.0]
xrange = [-0.1,10]

fig2 = plt.figure()
ax = fig2.add_subplot(111)
plt.ion()

fig2.show()
fig2.canvas.draw()

fig2.suptitle('live updated data', fontsize='18', fontweight='bold')
plt.xlabel('time, seconds', fontsize='14', fontstyle='italic')
plt.ylabel('potential, volts', fontsize='14', fontstyle='italic')
#line1, = plt.plot(timepoints, ydata,marker='o',markersize=4,linestyle='none',markerfacecolor='red')

#plt.ylim(yrange)
#plt.xlim(xrange)
plt.grid()

#ydata.append([float(data[1])*5.0/1024 ]) #, float(data[0])])
#timepoints.append(time()-start_time)

for i in range(20):
    ydata.append([1.1 * i **2, 1.1 * i **3]) #, float(data[0])]) , 1.5 *i
    timepoints.append(i)
    #update the plotted data
    #line1.set_xdata(timepoints)
    #line1.set_ydata(ydata)
    #ax.clear()    
    ax.set_xlim(xrange)
    ax.set_ylim(yrange)
    ax.plot(timepoints,ydata)

    #update the plot
    fig2.canvas.draw()
    fig2.canvas.flush_events()
    time.sleep(0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.set_x
line1.get_ydata()
# Out:
# [[0.0, 0.0], [1.1, 1.5]]

# %% [markdown]
# #ydata
# fig1 = plt.figure()
# plt.plot(timepoints, ydata)
# plt.show()

# %%
#https://matplotlib.org/examples/api/two_scales.html
fig, ax1 = plt.subplots()
#t = np.arange(0.01, 10.0, 0.01)
#s1 = np.exp(t)

xdata =   []
y1data =   [] # [0.0, 0.0] 
y2data =   [] # [0.0, 0.0] 

fig.suptitle('live updated data', fontsize='18', fontweight='bold')


#ax1.plot(t, s1, 'b-')
ax1.set_xlabel('time (s)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Period', color='b')
ax1.tick_params('y', colors='b')

xrange = [-0.1,10]
ax1.set_xlim(xrange)

ax2 = ax1.twinx()
#s2 = np.sin(2 * np.pi * t)

#ax2.plot(t, s2, 'r.')
ax2.set_ylabel('Veloc', color='r')
ax2.tick_params('y', colors='r')

#fig.tight_layout()
#plt.show()

#plt.ion()

fig.show()
fig.canvas.draw()

for i in range(20):
    xdata.append(i)
    y1data.append([1.1 * i **2]) #, float(data[0])]) , 1.5 *i
    y2data.append([np.exp(i)]) #, float(data[0])]) , 1.5 *i

    ax1.plot(xdata, y1data, 'b-')
    ax2.plot(xdata, y2data, 'r.')
    #update the plot
    fig.canvas.draw()
    fig.canvas.flush_events()
    time.sleep(0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1.lines.
